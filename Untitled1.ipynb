# %%
import numpy as np
df= np.load('liste3.npy')

# %%
import pandas as pd
d = pd.DataFrame(df)

# %%
d = d.sort_values(0)

# %%
d.tail()
# Out:
#                       0          1           2  \
# 4  2019-06-06T14:21:24Z   business    Business
# 3  2019-06-07T08:21:27Z  education   Education
# 2  2019-06-07T15:15:29Z   business    Business
# 1  2019-06-07T15:18:02Z      world  World news
# 0  2019-06-07T18:05:01Z        law         Law
#
#                                                    3  \
# 4  Ford workers devastated as Bridgend factory cl...
# 3    University guide 2020: Leeds Trinity University
# 2  US economy stumbles by creating just 75,000 jo...
# 1  Protests in Liberia over George Weah's failure...
# 0  Criminal barristers in England and Wales vote ...
#
#                                                    4  \
# 4  Rolling coverage of the latest economic and fi...
# 3  All you need to know about studying at Leeds T...
# 2  Dollar slides after America only created 75,00...
# 1  Ex-footballer under pressure 18 months into pr...
# 0  Strike in protest at low fees on 1 July will l...
#
# ...

# %%
d.head()
# Out:
#                           0         1         2  \
# 23690  2007-01-01T23:43:20Z  business  Business
# 23689  2007-01-01T23:55:50Z   uk-news   UK news
# 23688  2007-01-02T00:33:37Z   uk-news   UK news
# 23687  2007-01-02T11:16:40Z     money     Money
# 23686  2007-01-02T11:32:22Z  business  Business
#
#                                                        3  \
# 23690  If you don't remember the 1960s, this year may...
# 23689  Stern jobs warning as Bulgaria and Romania joi...
# 23688      Rail fares rise 'aims to tackle overcrowding'
# 23687  Patrick Barkham: New tickets  to ride - and th...
# 23686         UK industry figures 'disappointingly soft'
#
#                                                        4  \
# 23690  The world economy, including Britain's, looks ...
# 23689  · Workers face £1,000 fines if they breach res...
# 23688
# 23687
# 23686
#
#                                                        5
# 23690  The world economy, including Britain's, looks ...
# ...

# %%
d[100:150]
# Out:
#                           0              1          2  \
# 23590  2007-01-16T01:28:34Z       business   Business
# 23589  2007-01-16T09:59:59Z        uk-news    UK news
# 23588  2007-01-16T11:53:15Z      education  Education
# 23587  2007-01-16T15:39:56Z       business   Business
# 23586  2007-01-16T16:08:05Z       politics   Politics
# 23585  2007-01-16T17:01:10Z          media      Media
# 23584  2007-01-16T17:21:00Z  commentisfree    Opinion
# 23583  2007-01-16T17:29:53Z       business   Business
# 23582  2007-01-16T18:59:12Z  commentisfree    Opinion
# 23581  2007-01-16T19:14:06Z       business   Business
# 23580  2007-01-17T00:05:22Z       business   Business
# 23579  2007-01-17T00:14:44Z  commentisfree    Opinion
# 23578  2007-01-17T11:08:00Z        uk-news    UK news
# 23577  2007-01-17T12:13:10Z       business   Business
# 23576  2007-01-17T12:35:35Z       politics   Politics
# 23575  2007-01-17T14:20:53Z       business   Business
# ...

# %%
for i in range(9-1,3,-1):
    print(i)
# Out:
# 8
# 7
# 6
# 5
# 4

# %%
for i in range(5):
    print(8-i)
